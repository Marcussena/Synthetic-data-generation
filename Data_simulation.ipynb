# %% [markdown]
# #**Data simulation from scratch with Python**
#
# In this guide, I'll show some methods and techniques for creating simulated datasets from scratch using Python. Use it as a guide or keep it as reference for future data science and machine learning projects!

# %% [markdown]
# #1. Using Numpy
# ###The most famous Python library for dealing with linear algebra and numerical computing is also very useful for data generation.

# %%
# importing modules
from matplotlib import pyplot as plt
import numpy as np

# %% [markdown]
# ####In this example, I'll show how to create a dataset with noise having a linear relationship with the target values. It can be useful for testing linear regression models.

# %%
def create_data(N, w):
  """
  Creates a dataset with noise having a linear relationship with the target values.
  N: number of samples
  w: target values
  """
  # feature matrix with random data
  X = np.random.rand(N, 1) * 10
  # target values with noise normally distributed
  y = w[0] * X + w[1] + np.random.randn(N, 1)
  return X, y

# %%
# Visualize the data
X, y = create_data(200, [2, 1])

plt.figure(figsize=(10, 6))
plt.title('Simulated Linear Data')
plt.xlabel('X')
plt.ylabel('y')
plt.scatter(X, y)
plt.savefig('linear_data.jpg')
plt.show()

# %% [markdown]
# * Time Series data
#
# #### In this example, I'll use numpy to generate synthetic time series data with a linear trend and a seasonal component. That example is particularly useful for financial modeling and stock market prediction.

# %%
def create_time_series(N, w):
  """
  Creates a time series data with a linear trend and a seasonal component.
  N: number of samples
  w: target values
  """
  # time values
  time = np.arange(0,N)
  # linear trend
  trend = time * w[0]
  # seasonal component
  seasonal = np.sin(time * w[1])
  # noise
  noise = np.random.randn(N)
  # target values
  y = trend + seasonal + noise
  return time, y

# %%
time, y = create_time_series(100, [0.25, 0.2])

plt.figure(figsize=(10, 6))
plt.title('Simulated Time Series Data')
plt.xlabel('Time')
plt.ylabel('y')

plt.plot(time, y)
plt.savefig('time_series_data.jpg')
plt.show()

# %% [markdown]
# * Specific custom data

# %%
# create simulated data for analysis
np.random.seed(42)
# Generate a low-dimensional signal
low_dim_data = np.random.randn(100, 3)

# Create a random projection matrix to project into higher dimensions
projection_matrix = np.random.randn(3, 6)

# Project the low-dimensional data to higher dimensions
high_dim_data = np.dot(low_dim_data, projection_matrix)

# Add some noise to the high-dimensional data
noise = np.random.normal(loc=0, scale=0.5, size=(100, 6))
data_with_noise = high_dim_data + noise

X = data_with_noise

# %%
X.shape
# Out:
# (100, 6)

# %% [markdown]
# #2. Using Scikit-learn
# In addition to machine learning models, Scikit-learn also has data generators useful for building artificial datasets with controlled size and complexity.

# %% [markdown]
# *   Make classification
#
# The make_classification method can be used to create a random n-class dataset. That method allows the creation of datasets with a chosen number of observations, features, and classes.

# %%
from sklearn.datasets import make_classification

# %%
X, y = make_classification(n_samples=1000, n_features=5, n_classes=2)

# %%
import pandas as pd

#Visualize the first rows of the synthetic dataset
df = pd.DataFrame(X, columns=['feature1', 'feature2', 'feature3', 'feature4', 'feature5'])
df['target'] = y
df.head()
# Out:
#    feature1  feature2  feature3  feature4  feature5  target
# 0 -1.400075 -1.196055 -0.972962  1.049399  0.213197       0
# 1  2.710613  0.759937  1.987930 -1.099447 -1.749232       1
# 2  0.334656 -1.812906  0.373181  1.006864 -0.608883       1
# 3  0.328867 -1.207990  0.328298  0.645745  2.317675       0
# 4  0.813504 -1.099007  0.685526  0.465285  0.160528       1

# %% [markdown]
# * Make regression
#
# Similarly, the make_regression method is useful for creating datasets for regression analysis.

# %%
from sklearn.datasets import make_regression

# %%
X,y, coef = make_regression(n_samples=100, # number of observations
                            n_features=1,  # number of features
                            bias=10, # bias term
                            noise=50, # noise level
                            n_targets=1, # number of target values
                            random_state=0, # random seed
                            coef=True # return coefficients
                            )

# %%
plt.figure(figsize=(10, 6))
plt.title('Simulated Regression Data')
plt.xlabel('X')
plt.ylabel('y')
plt.scatter(X, y)
plt.savefig('regression_data2.jpg')
plt.show()

# %% [markdown]
# * Make blobs
#
# The make_blobs method of Scikit-learn can be very useful for clustering models such as K-means.

# %%
from sklearn.datasets import make_blobs

# %%
X,y = make_blobs(n_samples=300, # number of observations
                n_features=2, # number of features
                centers=3, # number of clusters
                cluster_std=0.5, # standard deviation of the clusters
                random_state=0)

# %%
# Visualize the data
plt.figure(figsize=(10, 6))
plt.title('Simulated Blobs Data')
plt.xlabel('X')
plt.ylabel('y')
plt.scatter(X[:,0], X[:,1], c=y)
plt.savefig('blobs_data.jpg')
plt.show()

# %% [markdown]
# # 3. Using SciPy
#
# The SciPy library is useful for generating simulated data from statistical distributions.

# %%
from scipy.stats import norm, binom, expon, poisson, gamma

# %%
# Normal Distribution
norm_data = norm.rvs(size=1000)

# %%
plt.figure(figsize=(10, 6))
plt.title('Simulated Normal Data')
plt.xlabel('X')
plt.ylabel('y')
plt.hist(norm_data, bins=50)
plt.savefig('normal_data.jpg')
plt.show()

# %%
# Binomial distribution
binom_data = binom.rvs(n=50, p=0.8, size=1000)

# %%
plt.figure(figsize=(10, 6))
plt.title('Simulated Binomial Data')
plt.xlabel('X')
plt.ylabel('y')
plt.hist(binom_data, bins=10)
plt.savefig('binomial_data.jpg')
plt.show()

# %%
# Exponential distribution
exp_data = expon.rvs(scale=.2, size=10000)

# %%
plt.figure(figsize=(10, 6))
plt.title('Simulated Exponential Data')
plt.xlabel('X')
plt.ylabel('y')
plt.hist(exp_data, bins=50)
plt.savefig('exponential_data.jpg')
plt.show()

# %% [markdown]
# # 4. Using Faker
#
# The Faker Library can create fake data for datasets that need user information such as name, address, email etc.

# %%
# !pip install Faker
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.8/1.8 MB 14.8 MB/s eta 0:00:00
# ...

# %%
from faker import Faker

# %%
def create_fake_data(N):
  """
  Creates a dataset with fake data.
  N: number of samples
  """
  fake = Faker()
  names = [fake.name() for _ in range(N)]
  addresses = [fake.address() for _ in range(N)]
  emails = [fake.email() for _ in range(N)]
  phone_numbers = [fake.phone_number() for _ in range(N)]
  fake_df = pd.DataFrame({'Name': names, 'Address': addresses, 'Email': emails, 'Phone Number': phone_numbers})
  return fake_df

# %%
fake_users = create_fake_data(100)
fake_users.head()
# Out:
#              Name                                            Address  \
# 0   Shane Baldwin             2542 James Rue\nDelacruzfort, OH 11233
# 1  Kimberly Davis                   Unit 6371 Box 7220\nDPO AP 39958
# 2   Mary Mcmillan  8642 Marcus Creek Suite 948\nPort Matthew, TN ...
# 3    Jillian Moon  94760 Austin Ridges Apt. 500\nWest Michael, KY...
# 4       Evan Buck  68507 Hayes Squares Suite 247\nDarrenfurt, WV ...
#
#                      Email         Phone Number
# 0      keith24@example.com   (861)714-3724x5832
# 1     mbradley@example.com  +1-389-250-0942x775
# 2  stephanie52@example.com    585-626-7352x6553
# 3    ytownsend@example.net        (249)205-6009
# 4       jody74@example.org  (711)886-3593x02030

# %% [markdown]
# # 5. Using Synthetic Data Vault (SDV)
#
# SDV is a Python library that allows users to generate entire datasets using existing data as seed.

# %%
# !pip install sdv
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 145.2/145.2 kB 2.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.2/139.2 kB 14.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.4/12.4 MB 43.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 51.9/51.9 kB 7.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.7/63.7 kB 8.5 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 169.9/169.9 kB 20.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 82.7/82.7 kB 11.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 41.0 MB/s eta 0:00:00
# ...
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# ...
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# ...
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# ...

# %%
from sdv.datasets.demo import download_demo

# %%
adult_data, metadata = download_demo(dataset_name='adult', modality='single_table')
adult_data.head()
# Out:
#    age workclass  fnlwgt     education  education-num      marital-status  \
# 0   27   Private  177119  Some-college             10            Divorced
# 1   27   Private  216481     Bachelors             13       Never-married
# 2   25   Private  256263    Assoc-acdm             12  Married-civ-spouse
# 3   46   Private  147640       5th-6th              3  Married-civ-spouse
# 4   45   Private  172822          11th              7            Divorced
#
#          occupation   relationship                race     sex  capital-gain  \
# 0      Adm-clerical      Unmarried               White  Female             0
# 1    Prof-specialty  Not-in-family               White  Female             0
# 2             Sales        Husband               White    Male             0
# 3  Transport-moving        Husband  Amer-Indian-Eskimo    Male             0
# 4  Transport-moving  Not-in-family               White    Male             0
#
#    capital-loss  hours-per-week native-country  label
# ...

# %%
from sdv.single_table import GaussianCopulaSynthesizer

# %%
# Use GaussianCopulaSynthesizer to train on the data
model = GaussianCopulaSynthesizer(metadata)
model.fit(adult_data)

# %%
# Generate Synthetic data
simulated_data = model.sample(100)
simulated_data.head()
# Out:
#    age  workclass  fnlwgt  education  education-num      marital-status  \
# 0   58    Private  155504    HS-grad             10  Married-civ-spouse
# 1   30  Local-gov  334589  Bachelors             11  Married-civ-spouse
# 2   23    Private  100675    HS-grad             10  Married-civ-spouse
# 3   45    Private  127020    HS-grad             14            Divorced
# 4   57    Private  258630    HS-grad              8  Married-civ-spouse
#
#           occupation relationship   race     sex  capital-gain  capital-loss  \
# 0      Other-service      Husband  White    Male         30799             0
# 1     Prof-specialty      Husband  White    Male         37400             0
# 2       Craft-repair         Wife  White  Female         45791             0
# 3      Other-service      Husband  White    Male         15383             8
# 4  Handlers-cleaners      Husband  Black    Male         51665            36
#
#    hours-per-week native-country  label
# ...
